# %% [markdown]
# # EyeAI — HYAMD Binary Ensemble
#
# This notebook runs the organized software-engineering pipeline for HYAMD binary AMD detection.
#
# Models:
# - RETFound + LoRA, 224x224
# - EfficientNetV2-S, 384x384

# %%
# Install dependencies and the local EyeAI package
# !pip install -q -r requirements.txt
# !pip install -q -e .

# %%
# Prepare HYAMD data
# !python scripts/prepare_hyamd.py --config configs/train_retfound_binary.yaml

# %%
# Train RETFound + LoRA binary model
# !python scripts/train_binary.py --config configs/train_retfound_binary.yaml

# %%
# Train EfficientNetV2-S binary model
# !python scripts/train_binary.py --config configs/train_efficientnetv2_binary.yaml

# %% [markdown]
# ## Notes
#
# After training both models, use the saved validation prediction files for ensemble threshold tuning.
